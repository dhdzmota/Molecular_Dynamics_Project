# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Read data from the files
with open('../FC/Results/initial_trial4.txt','r') as fout:
    data_values = fout.read()

# Clean and separate data
values = data_values.split('Mbytes\n')[1].split('\nLoop time')[0].split('\n')
# Order data in a list
clean_values = [list(filter(lambda x: x !='', values[i].split(' '))) for i in range(len(values))]

# Create a Dataframe
dataframe = pd.DataFrame(clean_values[1:],columns=clean_values[0], dtype=float)
dataframe.head()
# Out:
#    Step  Time       Temp     E_pair     PotEng     KinEng     TotEng  E_bond  \
# 0   0.0  0.00  300.00000  5373839.2  5373839.2  3886.3801  5377725.6     0.0
# 1   1.0  0.01  323.41340  5373535.4  5373535.4  4189.6914  5377725.1     0.0
# 2   2.0  0.02  396.43380  5372588.1  5372588.1  5135.6415  5377723.7     0.0
# 3   3.0  0.03  519.02800  5370997.8  5370997.8  6723.8003  5377721.6     0.0
# 4   4.0  0.04  691.14043  5368765.3  5368765.3  8953.4481  5377718.8     0.0
#
#        Press     Volume   Density
# 0  2730470.3  63205.652  1.626280
# 1  2730688.4  63205.661  1.626279
# 2  2731380.4  63205.689  1.626279
# 3  2732546.6  63205.735  1.626278
# 4  2734188.2  63205.799  1.626276

# %%
plt.figure()
plt.plot(dataframe.Step, dataframe.Temp)
plt.grid()
#plt.xlim(0,10)
#plt.ylim(0,1000)
plt.xlabel('Step')
plt.ylabel('Temperature')
plt.title('Temperature')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(dataframe.Step, dataframe.PotEng, label='Potential')
plt.plot(dataframe.Step, dataframe.KinEng, label='Kinetic')
plt.plot(dataframe.Step, dataframe.TotEng, label='Total')

plt.legend()
plt.grid()
plt.xlabel('Step')
plt.ylabel('Energy')
plt.title('Energies')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Energies')

# %%
plt.figure()
plt.plot(dataframe.Step, dataframe.Density)
plt.grid()
plt.xlabel('Step')
plt.ylabel('Density')
plt.title('Density')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Density')

# %%
plt.figure()
plt.grid()
plt.xlabel('Step')
plt.ylabel('Volume')
plt.title('Volume')
plt.plot(dataframe.Step, dataframe.Volume)
# Out:
# <img src="data:image/png;base64,..." width="640">
