# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Read data from the files
with open('../FC/Results/initial_trial2.txt','r') as fout:
    data_values = fout.read()

# Clean and separate data
values = data_values.split('Mbytes\n')[1].split('\nLoop time')[0].split('\n')
# Order data in a list
clean_values = [list(filter(lambda x: x !='', values[i].split(' '))) for i in range(len(values))]

# Create a Dataframe
dataframe = pd.DataFrame(clean_values[1:],columns=clean_values[0], dtype=float)
dataframe.head()
# Out:
#    Step   Time      Temp     E_pair     PotEng     KinEng     TotEng  E_bond  \
# 0   0.0  0.000  0.000000  5373839.2  5373839.2   0.000000  5373839.2     0.0
# 1   1.0  0.001  0.248067  5373836.0  5373836.0   3.213609  5373839.2     0.0
# 2   2.0  0.002  0.992267  5373826.3  5373826.3  12.854422  5373839.2     0.0
# 3   3.0  0.003  2.232597  5373810.2  5373810.2  28.922396  5373839.2     0.0
# 4   4.0  0.004  3.969050  5373787.7  5373787.7  51.417457  5373839.1     0.0
#
#        Press     Volume  Density
# 0  2727659.5  63205.652  1.62628
# 1  2727661.9  63205.652  1.62628
# 2  2727669.1  63205.652  1.62628
# 3  2727681.0  63205.653  1.62628
# 4  2727697.6  63205.653  1.62628

# %%
plt.figure()
plt.plot(dataframe.Step, dataframe.Temp)
plt.grid()

plt.xlabel('Step')
plt.ylabel('Temperature')
plt.title('Temperature')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(dataframe.Step, dataframe.PotEng, label='Potential')
plt.plot(dataframe.Step, dataframe.KinEng, label='Kinetic')
plt.plot(dataframe.Step, dataframe.TotEng, label='Total')

plt.legend()
plt.grid()
plt.xlabel('Step')
plt.ylabel('Energy')
plt.title('Energies')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Energies')

# %%
plt.figure()
plt.plot(dataframe.Step, dataframe.Density)
plt.grid()
plt.xlabel('Step')
plt.ylabel('Density')
plt.title('Density')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Density')

# %%
plt.figure()
plt.grid()
plt.xlabel('Step')
plt.ylabel('Volume')
plt.title('Volume')
plt.plot(dataframe.Step, dataframe.Volume)
# Out:
# <img src="data:image/png;base64,..." width="640">
